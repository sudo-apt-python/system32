# %% [markdown]
# #Yuvraj Patil
# RBT21CB016
#
# Machine Learning

# %% [markdown]
# #Aim
# To understand market basket analysis using apriori algorithm

# %% [markdown]
# #Objectives
# The Apriori algorithm is a classic algorithm for market basket analysis, which is a technique for identifying frequently co-occurring items in transactional datasets. The algorithm aims to uncover patterns in customer purchasing behavior and uncover relationships between products that can be used for various purposes, such as product placement, promotional strategies, and inventory management.
# Here are some specific objectives for a practical assignment involving the Apriori algorithm:
# 1.	Implement the Apriori algorithm from scratch: This objective involves understanding the algorithm's steps and coding it in a chosen programming language (e.g., Python, R).
# 2.	Apply the Apriori algorithm to a market basket dataset: This objective involves loading, preprocessing, and analyzing a dataset containing customer transactions and product IDs.
# 3.	Identify frequent itemsets and association rules: This objective involves setting appropriate support and confidence thresholds and extracting frequent itemsets and association rules from the dataset.
# 4.	Evaluate the quality of the discovered rules: This objective involves evaluating the lift and conviction of the discovered association rules to assess their strength and relevance.
# 5.	Interpret and visualize the results: This objective involves analyzing the discovered patterns, interpreting their business implications, and visualizing them using appropriate charts and graphs.
# 6.	Compare the Apriori algorithm with other market basket analysis techniques: This objective involves comparing the performance and effectiveness of the Apriori algorithm to other techniques, such as FP-growth or Eclat.

# %% [markdown]
# #Theory
# The Apriori algorithm is a level-wise approach for identifying frequent itemsets in transactional datasets. It starts by finding all frequent itemsets of size 1 (single items) and then iteratively extends these itemsets to find larger frequent itemsets. The algorithm uses support and confidence measures to determine which itemsets are considered frequent and which association rules are deemed relevant.
#
# •	Support: Support represents the proportion of transactions that contain a given itemset. It indicates how frequently a particular combination of items appears together.
# •	Confidence: Confidence represents the conditional probability that if a transaction contains a particular item, it will also contain another item or itemset. It indicates the strength of the association between items.
#
# The Apriori algorithm utilizes these measures to identify frequent itemsets and generate association rules that represent meaningful patterns in customer purchasing behavior.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from mlxtend.preprocessing import TransactionEncoder
from mpl_toolkits.mplot3d import Axes3D
import networkx as nx

# %%
basket = pd.read_csv("/content/Groceries_dataset.csv")
display(basket.head())
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    Member_number        Date   itemDescription
# 0           1808  21-07-2015    tropical fruit
# 1           2552  05-01-2015        whole milk
# 2           2300  19-09-2015         pip fruit
# 3           1187  12-12-2015  other vegetables
# 4           3037  01-02-2015        whole milk

# %%
basket.itemDescription = basket.itemDescription.transform(lambda x: [x])
basket = basket.groupby(['Member_number','Date']).sum()['itemDescription'].reset_index(drop=True)

encoder = TransactionEncoder()
transactions = pd.DataFrame(encoder.fit(basket).transform(basket), columns=encoder.columns_)
display(transactions.head())
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    Instant food products  UHT-milk  abrasive cleaner  artif. sweetener  \
# 0                  False     False             False             False
# 1                  False     False             False             False
# 2                  False     False             False             False
# 3                  False     False             False             False
# 4                  False     False             False             False
#
#    baby cosmetics   bags  baking powder  bathroom cleaner   beef  berries  \
# 0           False  False          False             False  False    False
# ...

# %%
frequent_itemsets = apriori(transactions, min_support= 6/len(basket), use_colnames=True, max_len = 2)
rules = association_rules(frequent_itemsets, metric="lift",  min_threshold = 1.5)
display(rules.head())
print("Rules identified: ", len(rules))
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#        antecedents         consequents  antecedent support  \
# 0    (butter milk)          (UHT-milk)            0.017577
# 1       (UHT-milk)       (butter milk)            0.021386
# 2  (cream cheese )          (UHT-milk)            0.023658
# 3       (UHT-milk)     (cream cheese )            0.021386
# 4           (soda)  (artif. sweetener)            0.097106
#
#    consequent support   support  confidence      lift  leverage  conviction  \
# 0            0.021386  0.000601    0.034221  1.600131  0.000226    1.013289
# 1            0.017577  0.000601    0.028125  1.600131  0.000226    1.010854
# ...

# %%
sns.set(style = "whitegrid")
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(projection = '3d')


x = rules['support']
y = rules['confidence']
z = rules['lift']

ax.set_xlabel("Support")
ax.set_ylabel("Confidence")
ax.set_zlabel("Lift")

ax.scatter(x, y, z)
ax.set_title("3D Distribution of Association Rules")

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
def draw_network(rules, rules_to_show):
  # Directional Graph from NetworkX
  network = nx.DiGraph()

  # Loop through number of rules to show
  for i in range(rules_to_show):

    # Add a Rule Node
    network.add_nodes_from(["R"+str(i)])
    for antecedents in rules.iloc[i]['antecedents']:
        # Add antecedent node and link to rule
        network.add_nodes_from([antecedents])
        network.add_edge(antecedents, "R"+str(i),  weight = 2)

    for consequents in rules.iloc[i]['consequents']:
        # Add consequent node and link to rule
        network.add_nodes_from([consequents])
        network.add_edge("R"+str(i), consequents,  weight = 2)

  color_map=[]

  # For every node, if it's a rule, colour as Black, otherwise Orange
  for node in network:
       if re.compile("^[R]\d+$").fullmatch(node) != None:
            color_map.append('black')
       else:
            color_map.append('orange')

  # Position nodes using spring layout
  pos = nx.spring_layout(network, k=16, scale=1)
  # Draw the network graph
  nx.draw(network, pos, node_color = color_map, font_size=8)

  # Shift the text position upwards
  for p in pos:
      pos[p][1] += 0.12

  nx.draw_networkx_labels(network, pos)
  plt.title("Network Graph for Association Rules")
  plt.show()

draw_network(rules, 10)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <>:24: DeprecationWarning: invalid escape sequence '\d'
# <>:24: DeprecationWarning: invalid escape sequence '\d'
# <ipython-input-10-ae85e4688f54>:24: DeprecationWarning: invalid escape sequence '\d'
#   if re.compile("^[R]\d+$").fullmatch(node) != None:

# %%
milk_rules = rules[rules['consequents'].astype(str).str.contains('whole milk')]
milk_rules = milk_rules.sort_values(by=['lift'],ascending = [False]).reset_index(drop = True)

display(milk_rules.head())
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#           antecedents   consequents  antecedent support  consequent support  \
# 0            (brandy)  (whole milk)            0.002540            0.157923
# 1          (softener)  (whole milk)            0.002740            0.157923
# 2      (canned fruit)  (whole milk)            0.001403            0.157923
# 3             (syrup)  (whole milk)            0.001403            0.157923
# 4  (artif. sweetener)  (whole milk)            0.001938            0.157923
#
#     support  confidence      lift  leverage  conviction  zhangs_metric
# 0  0.000869    0.342105  2.166281  0.000468    1.279957       0.539750
# ...

# %% [markdown]
# #Conclusion :
# Successfully implemented apriori algorithm and understood the market basket analysis
